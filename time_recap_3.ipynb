# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
df = pd.read_csv("macrodata.csv",index_col=0,parse_dates=True)
df
# Out:
#             year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 1959-03-31  1959        1   2710.349    1707.4   286.898   470.045   1886.9
# 1959-06-30  1959        2   2778.801    1733.7   310.859   481.301   1919.7
# 1959-09-30  1959        3   2775.488    1751.8   289.226   491.260   1916.4
# 1959-12-31  1959        4   2785.204    1753.7   299.356   484.052   1931.3
# 1960-03-31  1960        1   2847.699    1770.5   331.722   462.199   1955.5
# ...          ...      ...        ...       ...       ...       ...      ...
# 2008-09-30  2008        3  13324.600    9267.7  1990.693   991.551   9838.3
# 2008-12-31  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4
# 2009-03-31  2009        1  12925.410    9209.2  1558.494   996.287   9926.4
# 2009-06-30  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5
# 2009-09-30  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6
#
# ...

# %%
gdp_cycle,gdp_trend = hpfilter(df["realgdp"],lamb=1600)

# %%
gdp_trend.plot()
# Out:
# <AxesSubplot:>

# %%
gdp_cycle.plot()
# Out:
# <AxesSubplot:>

# %%
df["trend"]=gdp_trend

# %%
df[["realgdp","trend"]].plot()
# Out:
# <AxesSubplot:>

# %%
df[["realgdp","trend"]]["2005-01-01":].plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#             year  quarter    realgdp  realcons   realinv  realgovt  realdpi  \
# 1959-03-31  1959        1   2710.349    1707.4   286.898   470.045   1886.9
# 1959-06-30  1959        2   2778.801    1733.7   310.859   481.301   1919.7
# 1959-09-30  1959        3   2775.488    1751.8   289.226   491.260   1916.4
# 1959-12-31  1959        4   2785.204    1753.7   299.356   484.052   1931.3
# 1960-03-31  1960        1   2847.699    1770.5   331.722   462.199   1955.5
# ...          ...      ...        ...       ...       ...       ...      ...
# 2008-09-30  2008        3  13324.600    9267.7  1990.693   991.551   9838.3
# 2008-12-31  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4
# 2009-03-31  2009        1  12925.410    9209.2  1558.494   996.287   9926.4
# 2009-06-30  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5
# 2009-09-30  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6
#
# ...

# %%
df2 = pd.read_csv('UMTMVS.csv',index_col="DATE",parse_dates=True)

# %%
df2
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0
# ...              ...
# 2018-09-01  516992.0
# 2018-10-01  527031.0
# 2018-11-01  495901.0
# 2018-12-01  490076.0
# 2019-01-01  466791.0
#
# [325 rows x 1 columns]

# %%
df2.loc["2008-01-01":"2008-12-31"].idxmax()
# Out:
# UMTMVS   2008-06-01
# dtype: datetime64[ns]

# %%
df2.loc["2008-01-01":"2008-12-31"].max()
# Out:
# UMTMVS    510081.0
# dtype: float64

# %%
df2.loc["2008-01-01":"2008-12-31"]
# Out:
#               UMTMVS
# DATE
# 2008-01-01  432307.0
# 2008-02-01  442996.0
# 2008-03-01  474592.0
# 2008-04-01  475667.0
# 2008-05-01  490500.0
# 2008-06-01  510081.0
# 2008-07-01  476948.0
# 2008-08-01  482530.0
# 2008-09-01  471799.0
# 2008-10-01  450521.0
# 2008-11-01  383475.0
# 2008-12-01  377578.0

# %%
df2[df2["UMTMVS"]>=510081.0]
# Out:
#               UMTMVS
# DATE
# 2008-06-01  510081.0
# 2014-03-01  513700.0
# 2014-06-01  516935.0
# 2014-09-01  512988.0
# 2018-03-01  518285.0
# 2018-05-01  515105.0
# 2018-06-01  525660.0
# 2018-08-01  529157.0
# 2018-09-01  516992.0
# 2018-10-01  527031.0

# %%
df_post_peak = df2.loc['2008-06-01':]

# %%
df2
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0
# ...              ...
# 2018-09-01  516992.0
# 2018-10-01  527031.0
# 2018-11-01  495901.0
# 2018-12-01  490076.0
# 2019-01-01  466791.0
#
# [325 rows x 1 columns]

# %%
df_post_peak[df_post_peak>=510081].dropna()
# Out:
#               UMTMVS
# DATE
# 2008-06-01  510081.0
# 2014-03-01  513700.0
# 2014-06-01  516935.0
# 2014-09-01  512988.0
# 2018-03-01  518285.0
# 2018-05-01  515105.0
# 2018-06-01  525660.0
# 2018-08-01  529157.0
# 2018-09-01  516992.0
# 2018-10-01  527031.0

# %%
len(df2.loc['2008-06-01':'2014-03-01'])
# Out:
# 70
