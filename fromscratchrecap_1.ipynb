# %%
import pandas as pd
import numpy as np

# %%
t = np.random.randn(10,2)

# %%
df = pd.DataFrame(t,columns=["a","b"])

# %%
df.head()
# Out:
#           a         b
# 0  0.444013 -0.155774
# 1 -0.212977 -1.042800
# 2 -1.530564  0.542317
# 3  0.044165  0.981341
# 4  1.293573  0.196233

# %%
df = pd.read_csv("df3.csv")
df
# Out:
#          weekday  produced  defective
# 0       1.Monday        73          7
# 1      2.Tuesday        75         10
# 2    3.Wednesday        86          7
# 3     4.Thursday        64          7
# 4       5.Friday        70          6
# ..           ...       ...        ...
# 495     1.Monday        62          8
# 496    2.Tuesday        73         10
# 497  3.Wednesday        79          7
# 498   4.Thursday        78          6
# 499     5.Friday        55          5
#
# [500 rows x 3 columns]

# %%
df[["produced","weekday"]].boxplot(by="weekday",figsize=(14,5));

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.produced.plot.kde(grid=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dfs = pd.read_csv("starbucks.csv")
dfs
# Out:
#             Date    Close    Volume
# 0     2015-01-02  38.0061   6906098
# 1     2015-01-05  37.2781  11623796
# 2     2015-01-06  36.9748   7664340
# 3     2015-01-07  37.8848   9732554
# 4     2015-01-08  38.4961  13170548
# ...          ...      ...       ...
# 1001  2018-12-24  60.5600   6323252
# 1002  2018-12-26  63.0800  16646238
# 1003  2018-12-27  63.2000  11308081
# 1004  2018-12-28  63.3900   7712127
# 1005  2018-12-31  64.4000   7690183
#
# [1006 rows x 3 columns]

# %%
dfs = pd.read_csv("starbucks.csv",index_col="Date",parse_dates=True)
dfs
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1006 entries, 2015-01-02 to 2018-12-31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1006 non-null   float64
#  1   Volume  1006 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 23.6 KB

# %%
dfs["Close"].resample(rule="M").max().plot.bar(figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs.rolling(window=7).min().head(50)
# Out:
#               Close      Volume
# Date
# 2015-01-02      NaN         NaN
# 2015-01-05      NaN         NaN
# 2015-01-06      NaN         NaN
# 2015-01-07      NaN         NaN
# 2015-01-08      NaN         NaN
# 2015-01-09      NaN         NaN
# 2015-01-12  36.9748   6906098.0
# 2015-01-13  36.9748   7664340.0
# 2015-01-14  36.9748   7664340.0
# 2015-01-15  37.1381   8126602.0
# 2015-01-16  37.1381   8126602.0
# 2015-01-20  37.1381   8126602.0
# 2015-01-21  37.1381   8126602.0
# 2015-01-22  37.1381   8126602.0
# 2015-01-23  37.1381   8126602.0
# 2015-01-26  37.1381   8126602.0
# 2015-01-27  37.6188   9015502.0
# 2015-01-28  37.9058  10738304.0
# 2015-01-29  37.9361  10844182.0
# 2015-01-30  38.6128  10070456.0
# 2015-02-02  40.8482  10070456.0
# 2015-02-03  40.8482   9252426.0
# 2015-02-04  40.8482   9252426.0
# 2015-02-05  40.8482   7598672.0
# 2015-02-06  40.8482   7598672.0
# 2015-02-09  40.8482   6911614.0
# 2015-02-10  41.0629   6911614.0
# 2015-02-11  41.4469   6466910.0
# ...

# %%
dfs.head(50)
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# 2015-01-09  37.2361  27556706
# 2015-01-12  37.4415  10021486
# 2015-01-13  37.7401  11040702
# 2015-01-14  37.5301   9295084
# 2015-01-15  37.1381   8126602
# 2015-01-16  37.6188   9015502
# 2015-01-20  37.9058  10738304
# 2015-01-21  37.9361  10844182
# 2015-01-22  38.6128  23913056
# 2015-01-23  41.1702  38107194
# 2015-01-26  41.1235  14098574
# 2015-01-27  41.2262  10995808
# 2015-01-28  40.8645  11963202
# 2015-01-29  41.5575  12475860
# 2015-01-30  40.8482  10070456
# 2015-02-02  41.0629  13638832
# 2015-02-03  41.4469   9252426
# 2015-02-04  41.5453  11496698
# 2015-02-05  41.9856   7598672
# 2015-02-06  41.6858   7835332
# 2015-02-09  41.6015   6911614
# 2015-02-10  42.7069  12469500
# 2015-02-11  42.5242   6466910
# 2015-02-12  43.0090   7197558
# 2015-02-13  42.8942   6109522
# ...

# %%
dfs.rolling(window=7).mean().head(50)
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07
# 2015-01-16  37.600114  1.260380e+07
# 2015-01-20  37.515786  1.225634e+07
# 2015-01-21  37.615786  9.868837e+06
# 2015-01-22  37.783114  1.185335e+07
# 2015-01-23  38.273129  1.571999e+07
# 2015-01-26  38.786471  1.640620e+07
# 2015-01-27  39.370486  1.681609e+07
# 2015-01-28  39.834157  1.723719e+07
# 2015-01-29  40.355829  1.748541e+07
# 2015-01-30  40.771843  1.737488e+07
# 2015-02-02  41.121857  1.590713e+07
# 2015-02-03  41.161386  1.178502e+07
# 2015-02-04  41.221643  1.141333e+07
# 2015-02-05  41.330129  1.092802e+07
# 2015-02-06  41.447457  1.033833e+07
# ...

# %%
dfs["Close"].plot(figsize=(12,6))
dfs.rolling(window=3).mean()["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs["Close"].plot(figsize=(12,6))
dfs.rolling(window=7).mean()["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs["close:30"] = dfs["Close"].rolling(window=7).mean()

# %%
dfs
# Out:
#               Close    Volume   close:30
# Date
# 2015-01-02  38.0061   6906098        NaN
# 2015-01-05  37.2781  11623796        NaN
# 2015-01-06  36.9748   7664340        NaN
# 2015-01-07  37.8848   9732554        NaN
# 2015-01-08  38.4961  13170548        NaN
# ...             ...       ...        ...
# 2018-12-24  60.5600   6323252  63.270000
# 2018-12-26  63.0800  16646238  62.947143
# 2018-12-27  63.2000  11308081  62.765714
# 2018-12-28  63.3900   7712127  62.547143
# 2018-12-31  64.4000   7690183  62.595714
#
# [1006 rows x 3 columns]

# %%
dfs[["Close","close:30"]].plot(figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
title = "TITLE"
xlabel = "Date"
ylabel = "Close"

# %%
ax =  dfs["Close"].plot(figsize=(12,6),title=title)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'Close')]

# %%
ax = dfs["Close"].plot(figsize=(12,6),title=title)
ax.autoscale(axis="both", tight=True)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'Close')]

# %%
dfs["Close"]["2017-01-01":"2017-12-31"]
# Out:
# Date
# 2017-01-03    53.1100
# 2017-01-04    53.7241
# 2017-01-05    54.1750
# 2017-01-06    54.8179
# 2017-01-09    55.8446
#                ...
# 2017-12-22    56.0018
# 2017-12-26    55.8454
# 2017-12-27    55.9724
# 2017-12-28    56.5002
# 2017-12-29    56.1288
# Name: Close, Length: 251, dtype: float64

# %%
dfs["Close"]["2017-01-01":"2017-12-31"].plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs["Close"].plot(figsize=(16,4),xlim=["2017-01-01","2017-12-31"],ls="--",c="blue")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs["Close"].plot(figsize=(16,4),ylim=[33,76],ls="--",c="blue")
# Out:
# <AxesSubplot:xlabel='Date'>
