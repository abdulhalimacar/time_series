# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv("df2.csv")
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2["a"].plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df2["a"].plot.line()
# Out:
# <AxesSubplot:>

# %%
df2["c"].plot.line(figsize=(10,3), ls="-",c="green",lw=9)
# Out:
# <AxesSubplot:>

# %%
title = "my title"
xlabel= "x_label"
ylabel="y_label"

# %%
ax = df2["c"].plot.line(figsize=(10,3), ls="-",c="green",lw=9,title=title)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0.5, 0, 'x_label'), Text(0, 0.5, 'y_label')]

# %%
ax = df2.plot()
ax.legend(loc=0, bbox_to_anchor=(1,1))

# %%
df3 = pd.read_csv("df3.csv")
df3
# Out:
#          weekday  produced  defective
# 0       1.Monday        73          7
# 1      2.Tuesday        75         10
# 2    3.Wednesday        86          7
# 3     4.Thursday        64          7
# 4       5.Friday        70          6
# ..           ...       ...        ...
# 495     1.Monday        62          8
# 496    2.Tuesday        73         10
# 497  3.Wednesday        79          7
# 498   4.Thursday        78          6
# 499     5.Friday        55          5
#
# [500 rows x 3 columns]

# %%
df3.plot.scatter(x="produced",y="defective",c="green",figsize=(10,5),s=60)
# Out:
# <AxesSubplot:xlabel='produced', ylabel='defective'>

# %%
df3["produced"].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3["produced"].plot.hist(edgecolor="k").autoscale(tight=True,axis="both",enable=True)

# %%
df3["produced"].plot.box(x="weekday")
# Out:
# <AxesSubplot:>

# %%
df3[["produced","weekday"]].boxplot(by="weekday");

# %%
df3["defective"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3["defective"].plot.kde(ls="--",lw=5)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.loc[:30].plot.area(stacked=False,alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
ax = df3.loc[:30].plot.area(stacked=False,alpha=0.4) 
ax.legend(loc=0, bbox_to_anchor=(1,0.66))

# %%
from datetime import datetime

# %%
my_year = 2020
my_month = 1
my_day = 2
my_hour = 13 
my_min = 30 
my_second = 15

# %%
my_date = datetime(my_year,my_month,my_day)
my_date
# Out:
# datetime.datetime(2020, 1, 2, 0, 0)

# %%
my_date2 = datetime(my_year,my_month,my_day,my_hour,my_min,my_second)
my_date2
# Out:
# datetime.datetime(2020, 1, 2, 13, 30, 15)

# %%
my_date2.day
# Out:
# 2

# %%
my_date2.hour
# Out:
# 13

# %%
np.arange(0,12,4)
# Out:
# array([0, 4, 8])

# %%
np.arange("2018-06-01","2018-06-23",7,dtype="datetime64[D]")
# Out:
# array(['2018-06-01', '2018-06-08', '2018-06-15', '2018-06-22'],
#       dtype='datetime64[D]')

# %%
np.arange("2018-06-01","2033-06-23",7,dtype="datetime64[Y]")
# Out:
# array(['2018', '2025', '2032'], dtype='datetime64[Y]')

# %%
np.arange("2019","2030",7,dtype="datetime64[Y]")
# Out:
# array(['2019', '2026'], dtype='datetime64[Y]')

# %%
pd.date_range("2020-01-01",periods=7,freq="D")
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.to_datetime(["1/2/2020","January 03, 2028"])
# Out:
# DatetimeIndex(['2020-01-02', '2028-01-03'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(["03/12/2023","09/12/2030"], format="%d/%m/%Y")
# Out:
# DatetimeIndex(['2023-12-03', '2030-12-09'], dtype='datetime64[ns]', freq=None)

# %%
data = np.random.randn(3,2)
cols = ["A","B"]
print(data)
# Out:
# [[ 1.42513911 -1.08256662]
#  [ 0.36845065 -0.16719401]
#  [ 0.08806217  0.15291966]]

# %%
idx = pd.date_range("2020-01-01",periods=3,freq="D")
dfx = pd.DataFrame(data, index=idx, columns=cols)
dfx
# Out:
#                    A         B
# 2020-01-01  1.425139 -1.082567
# 2020-01-02  0.368451 -0.167194
# 2020-01-03  0.088062  0.152920

# %%
dfx.index.max()
# Out:
# Timestamp('2020-01-03 00:00:00', freq='D')

# %%
dfx.index.argmax()
# Out:
# 2

# %%
dfs = pd.read_csv("starbucks.csv")

# %%
dfs
# Out:
#             Date    Close    Volume
# 0     2015-01-02  38.0061   6906098
# 1     2015-01-05  37.2781  11623796
# 2     2015-01-06  36.9748   7664340
# 3     2015-01-07  37.8848   9732554
# 4     2015-01-08  38.4961  13170548
# ...          ...      ...       ...
# 1001  2018-12-24  60.5600   6323252
# 1002  2018-12-26  63.0800  16646238
# 1003  2018-12-27  63.2000  11308081
# 1004  2018-12-28  63.3900   7712127
# 1005  2018-12-31  64.4000   7690183
#
# [1006 rows x 3 columns]

# %%
pwd
# Out:
# 'C:\\Users\\Acar47'

# %%
#how to make date column the index

# %%
dfs = pd.read_csv("starbucks.csv",index_col = "Date")
dfs
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
dfs.index
#here date column is not datetime but index only. we executed the code so we did wrong
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
dfs = pd.read_csv("starbucks.csv",index_col = "Date",parse_dates=True)
dfs
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
# ...             ...       ...
# 2018-12-24  60.5600   6323252
# 2018-12-26  63.0800  16646238
# 2018-12-27  63.2000  11308081
# 2018-12-28  63.3900   7712127
# 2018-12-31  64.4000   7690183
#
# [1006 rows x 2 columns]

# %%
dfs.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
dfs.resample(rule="A").mean()
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
dfs.resample(rule="A").max()
# Out:
#               Close    Volume
# Date
# 2015-12-31  59.8475  38107194
# 2016-12-31  58.0465  32820193
# 2017-12-31  62.4924  53454789
# 2018-12-31  68.3530  62091071

# %%
dfs["Close"].resample(rule="M").max().plot.bar(figsize=(16,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfs.shift(periods=1,freq="M").head()
# Out:
#               Close    Volume
# Date
# 2015-01-31  38.0061   6906098
# 2015-01-31  37.2781  11623796
# 2015-01-31  36.9748   7664340
# 2015-01-31  37.8848   9732554
# 2015-01-31  38.4961  13170548

# %%
dfs.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548
