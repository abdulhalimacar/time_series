# %%
import pandas as pd

# %%
df1 = pd.read_csv("df1.csv", index_col=0)
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2 = pd.read_csv("df2.csv")
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df3 = pd.read_csv("df3.csv")
df3
# Out:
#          weekday  produced  defective
# 0       1.Monday        73          7
# 1      2.Tuesday        75         10
# 2    3.Wednesday        86          7
# 3     4.Thursday        64          7
# 4       5.Friday        70          6
# ..           ...       ...        ...
# 495     1.Monday        62          8
# 496    2.Tuesday        73         10
# 497  3.Wednesday        79          7
# 498   4.Thursday        78          6
# 499     5.Friday        55          5
#
# [500 rows x 3 columns]

# %%
df1["A"].plot.hist();

# %%
df1["A"].plot.hist(edgecolor="b"); 

#edge color = b,g,r,c,m,y,k,w...

# %%
df1["A"].plot.hist(edgecolor="b").autoscale(enable=True,axis="both");

# %%
df1["A"].plot.hist(edgecolor="b").autoscale(enable=True,axis="both",tight=True);

# %%
df1["A"].plot.hist(bins=20,edgecolor="b",grid=True).autoscale(enable=True,axis="both",tight=True);

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df2.plot.line(y="a",figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
df2.plot.line(y=["a","b","c"],figsize=(10,4))
# Out:
# <AxesSubplot:>

# %%
df2.plot.line(y=["a","b","c"],figsize=(10,4),lw=4)
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.plot.scatter(x="A",y="B",cmap="coolwarm")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x="A",y="B",cmap="coolwarm",alpha=0.5)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2["a"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import numpy as np

# %%
np.random.randn(200,2)
#200 satır ve 2 sütunlu bir veri yapısı getir bana
# Out:
# array([[-6.89572252e-01,  2.50991283e-01],
#        [ 3.72403623e-02, -1.16791774e+00],
#        [-6.53865237e-01, -8.12323251e-01],
#        [-1.53492312e+00,  1.66357346e+00],
#        [-1.62300997e+00,  1.64569544e-01],
#        [-1.20201634e+00,  4.50903873e-01],
#        [-4.29701931e-01, -1.21031126e+00],
#        [-9.75541543e-01,  1.57484392e+00],
#        [ 7.62346946e-01,  4.99167684e-01],
#        [ 1.67855489e+00,  1.90495093e+00],
#        [ 8.87783333e-01, -1.13575423e+00],
#        [ 6.12784865e-01, -3.80102189e-01],
#        [-5.21173849e-01,  9.67573983e-01],
#        [ 1.24112913e+00,  2.83344232e-01],
#        [-3.10361030e-01, -6.63859558e-02],
#        [-1.56931883e+00,  1.69679241e+00],
#        [-1.39139200e+00, -7.65595192e-02],
#        [ 2.04278994e+00,  1.22017405e+00],
#        [-7.37252572e-02,  9.33025671e-01],
#        [ 3.23363842e-01,  1.33109640e+00],
#        [-2.17905708e-01, -1.38005483e-01],
#        [-4.71446751e-01, -2.78262708e-01],
# ...

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=["a","b"])

# %%
df
# Out:
#             a         b
# 0    0.173562  2.306489
# 1   -0.454624  0.331637
# 2    0.355394  0.200682
# 3   -1.545992  0.449539
# 4   -0.422427  0.340117
# ..        ...       ...
# 995  0.243361 -0.480463
# 996 -1.287825  2.544142
# 997  0.617309 -0.325595
# 998  0.955824 -0.887546
# 999  0.571090  0.311457
#
# [1000 rows x 2 columns]

# %%
df.plot.scatter(x="a",y="b")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x="a",y="b")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x="a",y="b",gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
np.random.randint(1,30,10)
# Out:
# array([27,  1, 26, 18, 17, 16, 19, 18, 22, 17])

# %%
np.random.randn(100,2)
# Out:
# array([[ 7.58427679e-01, -2.06465605e+00],
#        [ 5.72724031e-01, -1.88399158e+00],
#        [-8.83242060e-01, -1.05149278e+00],
#        [ 9.73683577e-01,  9.56540249e-01],
#        [-1.58790885e+00,  1.47753294e+00],
#        [-9.25906402e-01,  9.84931750e-01],
#        [ 7.81662886e-01,  1.45324014e+00],
#        [ 1.49244889e+00,  6.71647093e-01],
#        [ 1.29244477e+00, -1.39178813e+00],
#        [ 2.46467466e-01,  7.12143258e-01],
#        [-1.24911571e-01, -5.20058485e-01],
#        [-1.41036059e-01, -2.61239742e-02],
#        [-4.36965868e-01, -4.05124493e-01],
#        [-8.14267198e-01,  1.14718051e+00],
#        [ 5.74133482e-01,  4.07931760e-01],
#        [-9.75442221e-01, -5.69050533e-01],
#        [-1.16978889e-01,  1.95662272e+00],
#        [-3.67089014e-01,  2.59616652e-01],
#        [-1.61477470e+00,  1.41904721e-01],
#        [ 7.11451396e-02,  5.89457980e-01],
#        [-2.02447948e-01,  3.14561828e-01],
#        [-2.26308196e-01,  7.41190972e-01],
# ...
